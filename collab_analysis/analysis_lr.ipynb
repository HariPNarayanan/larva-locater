# %%
# %load_ext autoreload
# %autoreload 2

import tkinter
from tkinter import filedialog
tkinter.Tk().withdraw()   # hide the root Tk window; only the picker dialog appears
# Out:
# ''

# %%
import collab_io, collab_figures


filepath = filedialog.askdirectory()

df = collab_io.preprocess_collab(filepath)

print(df["Condition"].unique())   # sanity check folder parsing
print(df.head(3))

pi_df, centroid_df, vx_df, neighbour_df = collab_figures.collab_summary(df)
# Out:
# d:\Experiment Work\larva-locater Repo\larva-locater\collab_io.py:57: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.options.mode.use_inf_as_na = True
# ['dORN_Me_L_10-1' 'dORN_none_L_0' 'ORNGCaMPmcherry_none_L_0'
#  'WT_EA_R_10-3' 'WT_Me_L_10-1' 'WT_Me_R_10-1' 'WT_none_L_0']
#         Condition Genotype Odour Side Concentration    Trial  \
# 0  dORN_Me_L_10-1     dORN    Me    L          10-1  Trial 1
# 1  dORN_Me_L_10-1     dORN    Me    L          10-1  Trial 1
# 2  dORN_Me_L_10-1     dORN    Me    L          10-1  Trial 1
#
#                       Individual  Frame       X       Y     VX
# 0  dORN_Me_L_10-1_conv_fish0.csv  118.0  11.080  14.991  0.000
# 1  dORN_Me_L_10-1_conv_fish0.csv  119.0  11.185  14.898  0.104
# 2  dORN_Me_L_10-1_conv_fish0.csv  120.0  11.166  14.831 -0.018
